# %% [markdown]
# <a href="https://colab.research.google.com/github/larimscorrea/jd-introduction-python/blob/main/fifth_step.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
# Out:
# Mounted at /content/drive

# %%
df= pd.read_csv('/content/drive/MyDrive/Treinamentos/Bases de Dados/All.csv',delimiter ='\t')

# %%
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id  \
# 0  CA-2017-152156  06/02/2022  09/02/2022    Second Class    CG-12520
# 1  CA-2017-152156  06/02/2022  09/02/2022    Second Class    CG-12520
# 2  CA-2017-138688  10/09/2021  14/09/2021    Second Class    DV-13045
# 3  US-2016-108966  09/01/2021  16/01/2021  Standard Class    SO-20335
# 4  US-2016-108966  09/01/2021  16/01/2021  Standard Class    SO-20335
#
#         product_id         category sub_category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name   price    customer_name  \
# 0                  Bush Somerset Collection Bookcase  130.98      Claire Gute
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  170.79      Claire Gute
# 2  Self-Adhesive Address Labels for Typewriters b...    7.31  Darrin Van Huff
# 3      Bretford CR4500 Series Slim Rectangular Table  191.52   Sean O'Donnell
# 4                     Eldon Fold 'N Roll Cart System   13.98   Sean O'Donnell
#
#      segment        country          city      state  postal_code   region
# 0   Consumer  United States        Dallas      Texas      75217.0  Central
# 1   Consumer  United States        Dallas      Texas      75217.0  Central
# 2  Corporate  United States  Jacksonville    Florida      32216.0    South
# 3   Consumer  United States      Columbia  Tennessee      38401.0    South
# 4   Consumer  United States      Columbia  Tennessee      38401.0    South

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9795 entries, 0 to 9794
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       9795 non-null   object
#  1   order_date     9795 non-null   object
#  2   ship_date      9795 non-null   object
#  3   ship_mode      9795 non-null   object
#  4   customer_id    9795 non-null   object
#  5   product_id     9795 non-null   object
#  6   category       9795 non-null   object
#  7   sub_category   9795 non-null   object
#  8   product_name   9795 non-null   object
#  9   price          9795 non-null   float64
#  10  customer_name  9795 non-null   object
#  11  segment        9795 non-null   object
#  12  country        9795 non-null   object
#  13  city           9795 non-null   object
#  14  state          9795 non-null   object
#  15  postal_code    9742 non-null   float64
#  16  region         9795 non-null   object
# dtypes: float64(2), object(15)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#               price   postal_code
# count   9795.000000   9742.000000
# mean     101.759532  54166.230240
# std      381.081159  25727.921756
# min        0.440000   1810.000000
# 25%        7.780000  31907.000000
# 50%       22.700000  60505.000000
# 75%       89.580000  77070.000000
# max    22638.480000  98226.000000

# %%
df['profit'] = df['price']*0.2

# %%
df.describe(include='O')
# Out:
#               order_id  order_date   ship_date       ship_mode customer_id  \
# count             9795        9795        9795            9795        9795
# unique            4921        1230        1326               4         793
# top     CA-2018-100111  04/12/2021  25/12/2022  Standard Class    WB-21850
# freq                14          38          34            5855          35
#
#              product_id         category sub_category     product_name  \
# count              9795             9795         9795             9795
# unique             1861                3           17             1817
# top     OFF-PA-10001970  Office Supplies      Binders  Staple envelope
# freq                 19             5906         1492               47
#
#         customer_name   segment        country     city  state   region
# count            9795      9795           9795     9795   9795     9795
# unique            793         3              1      180     43        4
# top     William Brown  Consumer  United States  Chicago  Texas  Central
# freq               35      5096           9795     1208   1576     3898

# %% [markdown]
# ## **VISUALIZAÇÃO DE DADOS: MATPLOTLIB**

# %%
import matplotlib.pyplot as plt

# %%
#Crosstab
pd.crosstab(df['category'], df['state'], margins=True).style.background_gradient(cmap='Greys') #tabela multi-dimensional
# Out:
# <style type="text/css">
# #T_a0b4e_row0_col0, #T_a0b4e_row0_col1, #T_a0b4e_row0_col5, #T_a0b4e_row0_col11, #T_a0b4e_row0_col13, #T_a0b4e_row0_col14, #T_a0b4e_row0_col15, #T_a0b4e_row0_col17, #T_a0b4e_row0_col18, #T_a0b4e_row0_col19, #T_a0b4e_row0_col20, #T_a0b4e_row0_col21, #T_a0b4e_row0_col22, #T_a0b4e_row0_col23, #T_a0b4e_row0_col26, #T_a0b4e_row0_col33, #T_a0b4e_row0_col36, #T_a0b4e_row0_col38, #T_a0b4e_row0_col40, #T_a0b4e_row2_col2, #T_a0b4e_row2_col3, #T_a0b4e_row2_col4, #T_a0b4e_row2_col5, #T_a0b4e_row2_col6, #T_a0b4e_row2_col7, #T_a0b4e_row2_col8, #T_a0b4e_row2_col9, #T_a0b4e_row2_col10, #T_a0b4e_row2_col12, #T_a0b4e_row2_col13, #T_a0b4e_row2_col16, #T_a0b4e_row2_col24, #T_a0b4e_row2_col25, #T_a0b4e_row2_col27, #T_a0b4e_row2_col28, #T_a0b4e_row2_col29, #T_a0b4e_row2_col30, #T_a0b4e_row2_col31, #T_a0b4e_row2_col32, #T_a0b4e_row2_col34, #T_a0b4e_row2_col35, #T_a0b4e_row2_col36, #T_a0b4e_row2_col37, #T_a0b4e_row2_col39, #T_a0b4e_row2_col41, #T_a0b4e_row2_col42, #T_a0b4e_row2_col43 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_a0b4e_row0_col2 {
#   background-color: #e0e0e0;
#   color: #000000;
# }
# #T_a0b4e_row0_col3, #T_a0b4e_row0_col16, #T_a0b4e_row0_col29 {
#   background-color: #f9f9f9;
#   color: #000000;
# }
# #T_a0b4e_row0_col4, #T_a0b4e_row0_col37, #T_a0b4e_row0_col42 {
#   background-color: #f4f4f4;
#   color: #000000;
# }
# #T_a0b4e_row0_col6 {
#   background-color: #c6c6c6;
#   color: #000000;
# }
# #T_a0b4e_row0_col7, #T_a0b4e_row0_col27, #T_a0b4e_row2_col26 {
#   background-color: #fafafa;
#   color: #000000;
# }
# #T_a0b4e_row0_col8, #T_a0b4e_row0_col43, #T_a0b4e_row2_col11, #T_a0b4e_row2_col19, #T_a0b4e_row2_col23 {
#   background-color: #fbfbfb;
#   color: #000000;
# }
# #T_a0b4e_row0_col9, #T_a0b4e_row0_col10, #T_a0b4e_row2_col21 {
#   background-color: #f8f8f8;
#   color: #000000;
# }
# #T_a0b4e_row0_col12 {
#   background-color: #f6f6f6;
#   color: #000000;
# }
# #T_a0b4e_row0_col24 {
#   background-color: #eeeeee;
#   color: #000000;
# }
# #T_a0b4e_row0_col25, #T_a0b4e_row0_col28, #T_a0b4e_row2_col17, #T_a0b4e_row2_col18, #T_a0b4e_row2_col40 {
#   background-color: #fefefe;
#   color: #000000;
# }
# #T_a0b4e_row0_col30 {
#   background-color: #f3f3f3;
#   color: #000000;
# }
# #T_a0b4e_row0_col31, #T_a0b4e_row0_col32 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# #T_a0b4e_row0_col34, #T_a0b4e_row0_col35, #T_a0b4e_row2_col20, #T_a0b4e_row2_col38 {
#   background-color: #f7f7f7;
#   color: #000000;
# }
# #T_a0b4e_row0_col39 {
#   background-color: #f5f5f5;
#   color: #000000;
# }
# #T_a0b4e_row0_col41, #T_a0b4e_row2_col0 {
#   background-color: #fdfdfd;
#   color: #000000;
# }
# #T_a0b4e_row1_col0, #T_a0b4e_row1_col11, #T_a0b4e_row1_col36 {
#   background-color: #949494;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col1 {
#   background-color: #9e9e9e;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col2 {
#   background-color: #828282;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col3, #T_a0b4e_row1_col10, #T_a0b4e_row1_col16, #T_a0b4e_row1_col38, #T_a0b4e_row1_col41 {
#   background-color: #909090;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col4, #T_a0b4e_row1_col28 {
#   background-color: #8a8a8a;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col5 {
#   background-color: #767676;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col6, #T_a0b4e_row1_col34 {
#   background-color: #686868;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col7 {
#   background-color: #939393;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col8, #T_a0b4e_row1_col39 {
#   background-color: #8c8c8c;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col9 {
#   background-color: #818181;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col12, #T_a0b4e_row1_col21 {
#   background-color: #7a7a7a;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col13 {
#   background-color: #999999;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col14, #T_a0b4e_row1_col37 {
#   background-color: #757575;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col15 {
#   background-color: #b2b2b2;
#   color: #000000;
# }
# #T_a0b4e_row1_col17 {
#   background-color: #b4b4b4;
#   color: #000000;
# }
# #T_a0b4e_row1_col18 {
#   background-color: #989898;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col19 {
#   background-color: #898989;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col20 {
#   background-color: #8d8d8d;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col22 {
#   background-color: #393939;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col23 {
#   background-color: #cecece;
#   color: #000000;
# }
# #T_a0b4e_row1_col24, #T_a0b4e_row1_col29 {
#   background-color: #9a9a9a;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col25 {
#   background-color: #868686;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col26 {
#   background-color: #a9a9a9;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col27 {
#   background-color: #7f7f7f;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col30, #T_a0b4e_row2_col15 {
#   background-color: #dcdcdc;
#   color: #000000;
# }
# #T_a0b4e_row1_col31 {
#   background-color: #a8a8a8;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col32 {
#   background-color: #959595;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col33 {
#   background-color: #9f9f9f;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col35 {
#   background-color: #bbbbbb;
#   color: #000000;
# }
# #T_a0b4e_row1_col40 {
#   background-color: #979797;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col42 {
#   background-color: #575757;
#   color: #f1f1f1;
# }
# #T_a0b4e_row1_col43 {
#   background-color: #929292;
#   color: #f1f1f1;
# }
# #T_a0b4e_row2_col1, #T_a0b4e_row2_col14 {
#   background-color: #fcfcfc;
#   color: #000000;
# }
# #T_a0b4e_row2_col22 {
#   background-color: #e6e6e6;
#   color: #000000;
# }
# #T_a0b4e_row2_col33 {
#   background-color: #eaeaea;
#   color: #000000;
# }
# #T_a0b4e_row3_col0, #T_a0b4e_row3_col1, #T_a0b4e_row3_col2, #T_a0b4e_row3_col3, #T_a0b4e_row3_col4, #T_a0b4e_row3_col5, #T_a0b4e_row3_col6, #T_a0b4e_row3_col7, #T_a0b4e_row3_col8, #T_a0b4e_row3_col9, #T_a0b4e_row3_col10, #T_a0b4e_row3_col11, #T_a0b4e_row3_col12, #T_a0b4e_row3_col13, #T_a0b4e_row3_col14, #T_a0b4e_row3_col15, #T_a0b4e_row3_col16, #T_a0b4e_row3_col17, #T_a0b4e_row3_col18, #T_a0b4e_row3_col19, #T_a0b4e_row3_col20, #T_a0b4e_row3_col21, #T_a0b4e_row3_col22, #T_a0b4e_row3_col23, #T_a0b4e_row3_col24, #T_a0b4e_row3_col25, #T_a0b4e_row3_col26, #T_a0b4e_row3_col27, #T_a0b4e_row3_col28, #T_a0b4e_row3_col29, #T_a0b4e_row3_col30, #T_a0b4e_row3_col31, #T_a0b4e_row3_col32, #T_a0b4e_row3_col33, #T_a0b4e_row3_col34, #T_a0b4e_row3_col35, #T_a0b4e_row3_col36, #T_a0b4e_row3_col37, #T_a0b4e_row3_col38, #T_a0b4e_row3_col39, #T_a0b4e_row3_col40, #T_a0b4e_row3_col41, #T_a0b4e_row3_col42, #T_a0b4e_row3_col43 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a0b4e_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >state</th>
#       <th class="col_heading level0 col0" >Alabama</th>
#       <th class="col_heading level0 col1" >Arizona</th>
#       <th class="col_heading level0 col2" >Arkansas</th>
#       <th class="col_heading level0 col3" >California</th>
#       <th class="col_heading level0 col4" >Colorado</th>
#       <th class="col_heading level0 col5" >Connecticut</th>
#       <th class="col_heading level0 col6" >Delaware</th>
#       <th class="col_heading level0 col7" >Florida</th>
#       <th class="col_heading level0 col8" >Georgia</th>
#       <th class="col_heading level0 col9" >Idaho</th>
#       <th class="col_heading level0 col10" >Illinois</th>
#       <th class="col_heading level0 col11" >Indiana</th>
#       <th class="col_heading level0 col12" >Iowa</th>
#       <th class="col_heading level0 col13" >Kentucky</th>
#       <th class="col_heading level0 col14" >Louisiana</th>
#       <th class="col_heading level0 col15" >Maine</th>
#       <th class="col_heading level0 col16" >Maryland</th>
#       <th class="col_heading level0 col17" >Massachusetts</th>
#       <th class="col_heading level0 col18" >Michigan</th>
#       <th class="col_heading level0 col19" >Minnesota</th>
#       <th class="col_heading level0 col20" >Mississippi</th>
#       <th class="col_heading level0 col21" >Missouri</th>
#       <th class="col_heading level0 col22" >Montana</th>
#       <th class="col_heading level0 col23" >Nevada</th>
#       <th class="col_heading level0 col24" >New Hampshire</th>
#       <th class="col_heading level0 col25" >New Jersey</th>
#       <th class="col_heading level0 col26" >New Mexico</th>
#       <th class="col_heading level0 col27"

# %%
#Histograma
plt.hist(df['price'], bins=10000)
plt.xlim(0, 100) #define os limites para o eixo x
plt.xlabel('Preço') #define o título para o eixo x
plt.ylabel('Frequência') #define o título para o eixo y
plt.show() #assim como o print, imprime a imagem

# %%
#Analisando com limites diferentes
plt.hist(df['price'], bins=10000)
plt.xlim(0, 1000)
plt.xlabel('Preço') #define o título para o eixo x
plt.ylabel('Frequência')
plt.show() #como o print, imprime a imagem

# %%
# Gráfico de barras
plt.bar(df['category'],df['price'])
plt.show()

# %%
plt.plot(df['price'])
plt.show()

# %% [markdown]
# ## **SUBPLOTS**

# %%
#Outra forma de fazer os subplots

f, ax = plt.subplots(1,2, figsize=(8,3), dpi=150) # 1 linha, 2 colunas
ax[0].hist(df['price'], bins=10000)
ax[0].set_title('Distribuição dos Preços')

ax[1].bar(df['category'],df['price'])
ax[1].set_title('Distribuição preços por categoria')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **SEABORN**

# %%
import seaborn as sns #menos código

# %%
df['segment'].value_counts()
# Out:
# Consumer       5096
# Corporate      2953
# Home Office    1746
# Name: segment, dtype: int64

# %% [markdown]
# ## **PIE E COUNTPLOT**

# %% [markdown]
# Gráfico de pizza

# %%
df['segment'].value_counts().plot.pie(explode=[0.02,0.02,0.02], autopct='%0.2f%%'); #explode= margem de distancia das "fatias"

# %%
#Exemplo do que não fazer
df['sub_category'].value_counts().plot.pie(autopct='%0.2f%%');

# %% [markdown]
# ## **COUNTPLOT E HUE**

# %%
sns.countplot(data=df, x='segment'); #contando por categoria de produto

# %%
#Contar automaticamente dentro do gráfico
#hue=separação
sns.countplot('segment', hue='category', data=df);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Correlação
correlation = df.corr()
correlation
# Out:
#                 price  postal_code    profit
# price        1.000000    -0.020774  1.000000
# postal_code -0.020774     1.000000 -0.020774
# profit       1.000000    -0.020774  1.000000

# %%
#Mapa de calor de correção
plot = sns.heatmap(correlation, annot = True, fmt=".1f", linewidths=.6)

# %%
"""dados: conjunto de dados 2D que pode ser coagido em um ndarray.
vmin , vmax: Valores para ancorar o mapa de cores, caso contrário, eles são inferidos dos dados e de outros argumentos de palavra-chave.
cmap: O mapeamento de valores de dados para espaço de cores.
center: O valor no qual centralizar o mapa de cores ao plotar dados divergentes.
annot: se True, escreva o valor dos dados em cada célula.
fmt: código de formatação de string a ser usado ao adicionar anotações.
linewidths: Largura das linhas que irão dividir cada célula.
linecolor: cor das linhas que irão dividir cada célula.
cbar: se deve desenhar uma barra de cores."""

# %%
#Dispersão e regressão linear
sns.lmplot(data=df, x='postal_code', y= 'price');

# %% [markdown]
# ## **BOXPLOT**

# %%
plt.figure(figsize=(5,3), dpi=100) #configurando o tamanho e dpi pelo matplotlib
sns.boxplot(x='segment', y='price', data=df);

# %%
df_1 = df.loc[df['price']<100]

# %%
plt.figure(figsize=(5,3), dpi=100)
sns.boxplot( y='price', data=df_1);

# %%
plt.figure(figsize=(5,3), dpi=100)
sns.boxplot(x='category', y='price', data=df_1);

# %%
#Visualização horizontal
plt.figure(figsize=(5,3), dpi=100)
sns.boxplot(data=df_1, x='price', y='category', orient='h');

# %% [markdown]
# ## **VIOLINPLOT**

# %%
plt.figure(figsize=(5,3), dpi=100)
sns.violinplot(y='price', data=df_1) #basicamente a mesma coisa boxplot, mas nos atenta com as caudas

# %%
plt.figure(figsize=(5,3), dpi=100)
sns.violinplot(x='segment',y='price', data=df_1) #basicamente a mesma coisa boxplot, mas nos atenta com as caudas

# %%
sns.violinplot(data=df_1, x='price', y='category', orient='h');

# %% [markdown]
# ## **FACETGRID**

# %%
#Multiplos gráficos no mesmo canvas = gráficos inteligentes
g = sns.FacetGrid(df, col='category')
g.map(plt.hist, 'price', bins=18);

# %%
#Multiplos gráficos no mesmo canvas = gráficos inteligentes
g = sns.FacetGrid(df_1, col='category')
g.map(plt.hist, 'price', bins=18);

# %% [markdown]
# ## **SCATTERPLOT**

# %%
sns.scatterplot(x='category', y='price',
               palette='magma', data=df, sizes=(10, 200));

# %%
#Gráfico de área
plt.figure(figsize=(8,5), dpi=80)
sns.kdeplot(df['price'].loc[df['segment']=='Consumer'], shade=True, 
            color='g', label='Cap', alpha=0.7)
sns.kdeplot(df['price'].loc[df['segment']=='Corporate segment'], shade=True, 
            color='deeppink', label='Met', alpha=0.7)
sns.kdeplot(df['price'].loc[df['segment']=='Home Office'], shade=True, 
            color='dodgerblue', label='Int', alpha=0.7)
plt.title('Distribuição por segmento')
plt.show()

# %%
#Gráfico de área
plt.figure(figsize=(8,5), dpi=80)
sns.kdeplot(df_1['price'].loc[df['segment']=='Consumer'], shade=True, 
            color='g', label='Cap', alpha=0.7)
sns.kdeplot(df_1['price'].loc[df['segment']=='Corporate segment'], shade=True, 
            color='deeppink', label='Met', alpha=0.7)
sns.kdeplot(df_1['price'].loc[df['segment']=='Home Office'], shade=True, 
            color='dodgerblue', label='Int', alpha=0.7)
plt.title('Distribuição por segmento')
plt.show()

# %% [markdown]
# JHH

# %%
#Histograma
plt.hist(df['price'], bins=1000)
plt.xlim(0, 1000) #define os limites para o eixo x
plt.xlabel('Preço') #define o título para o eixo x
plt.ylabel('Frequência') #define o título para o eixo y
plt.savefig('my_plot.png')

# %% [markdown]
# JHHJ

# %%
import numpy as np

# %%
x = np.random.normal(10, 1, 150) # criando 15 elementos, com média 10, e desvio padrão 1
x1 = np.random.normal(10, 1, 1500)

# %%
#plot
plt.plot(x);

# %%
#plot
plt.hist(x);

# %%
#plot
plt.hist(x1);

# %%
#linspace
x = np.linspace(0,200,1000) # criando 1000 numeros igualmente espaçados num intervalo de 0 a 20

# %%
plt.plot(x)
plt.show()

# %%
y = 5*x - 5 # equação do primeiro grau

# %%
plt.plot(x,y)
plt.show()

# %%
y = 2*x**2 - 5*x +3 # equação do segundo grau

# %%
plt.plot(x,y)
plt.show()

# %%
y = 2*x**3 + 2*x**2 - 5*x +3 # equação do terceiro grau

# %%
plt.plot(x,y, label='plot1')
plt.plot(x*2,y, label='plot2')

plt.legend()
plt.show()

# %%
#normal
y = np.random.normal(8,2,1000) # criando 1000 elementos normalmente distribuidos, com uma média 8 e um desvio padrão de 2

# %%
#printando o histograma
plt.hist(y)
plt.show()

# %%
sns.distplot(y)
plt.show();
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
